# %% [markdown]
# <a href="https://colab.research.google.com/github/zsx8/R4DS/blob/main/1_4_3_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# install.packages("palmerpenguins")
library(palmerpenguins)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘palmerpenguins’
#
#
# The following objects are masked from ‘package:datasets’:
#
#     penguins, penguins_raw

# %% [markdown]
# 1. Make a bar plot of species of penguins, where you assign species to the y aesthetic. How is this plot different?
#
# A: Horizontal, not vertical.

# %%
ggplot(penguins, aes(y = fct_infreq(species))) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# 2. How are the following two plots different? Which aesthetic, color or fill, is more useful for changing the color of bars?
#
# ggplot(penguins, aes(x = species)) +
#   geom_bar(color = "red")
#
# ggplot(penguins, aes(x = species)) +
#   geom_bar(fill = "red")
#
#   A: 2nd one is more useful.

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar(color = "red")
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar(fill = "red")
# Out:
# plot without title

# %% [markdown]
# 3. What does the bins argument in geom_histogram() do?
#
# A: It represents number of "bins"/"bars" data split into.

# %%
ggplot(penguins, aes(x = body_mass_g)) +
  geom_histogram(bins = 10)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %% [markdown]
# 4. Make a histogram of the carat variable in the diamonds dataset that is available when you load the tidyverse package. Experiment with different binwidths. What binwidth reveals the most interesting patterns?

# %%
ggplot(diamonds, aes(x = carat)) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %%
ggplot(diamonds, aes(x = carat)) +
  geom_histogram(binwidth = 0.1)
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x = carat)) +
  geom_histogram(binwidth = 0.05)
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x = carat)) +
  geom_histogram(binwidth = 0.01)
# Out:
# plot without title
